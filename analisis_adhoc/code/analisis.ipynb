# %%
import pandas as pd

# Cargar datos
loans = pd.read_csv('../exports/fct_loan_financials.csv')
cohorts = pd.read_csv('../exports/fct_cohort_performance.csv')
pnl = pd.read_csv('../exports/fct_portfolio_pnl.csv')

print(f"✅ Loans: {len(loans):,} rows")
print(f"✅ Cohorts: {len(cohorts)} rows")
print(f"✅ P&L: {len(pnl)} rows")
# Out:
# ✅ Loans: 9,396 rows
# ✅ Cohorts: 14 rows
# ✅ P&L: 14 rows
